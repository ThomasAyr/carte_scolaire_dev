# %% [markdown]
# Chargement fichier et bibliothèques

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Charger le fichier CSV dans un DataFrame
data_carte_scolaire = pd.read_csv("../datasets/fr-en-occitanie-carte-scolaire-des-colleges-lycees-publics (1).csv", sep=";")
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data_carte_scolaire.head()
# Out:
#    code_region libelle_region  code_academie libelle_academie  \
# 0         76.0      OCCITANIE           11.0      MONTPELLIER
# 1         76.0      OCCITANIE           16.0         TOULOUSE
# 2         76.0      OCCITANIE           16.0         TOULOUSE
# 3         76.0      OCCITANIE           11.0      MONTPELLIER
# 4         76.0      OCCITANIE           11.0      MONTPELLIER
#
#    code_departement libelle_departement_eleve  code_postal  code_insee  \
# 0                30                      GARD      30100.0       30007
# 1                81                      TARN      81000.0       81004
# 2                31             HAUTE-GARONNE      31000.0       31555
# 3                30                      GARD      30100.0       30007
# 4                34                   HERAULT      34500.0       34032
#
#   com_name_upper lieu_dit  ...  code_rne libelle_commune  \
# 0           ALÈS      NaN  ...  0300002P            Alès
# 1           ALBI      NaN  ...  0810006S            Albi
# 2       TOULOUSE      NaN  ...  0310036W        Toulouse
# 3           ALÈS      NaN  ...  0300002P            Alès
# 4        BÉZIERS      NaN  ...  0340009A         Béziers
#
#                                  position                 adresse_uai  \
# 0   44.13007691581518, 4.0749894825204445        Place DE LA BELGIQUE
# 1  43.930219077875215, 2.1471694939735566  2 r Lices Georges Pompidou
# 2    43.6032751508944, 1.4398952901892104        3 allée Maurice Prin
# 3   44.13007691581518, 4.0749894825204445        Place DE LA BELGIQUE
# 4    43.34343324346055, 3.210700877404225        1  RUE IGNACE BRUNEL
#
#                               appellation_officielle  \
# 0  Lycée polyvalent Jean-Baptiste Dumas, Lycée de...
# 1                            Lycée général Lapérouse
# 2                     Lycée général Pierre de Fermat
# 3  Lycée polyvalent Jean-Baptiste Dumas, Lycée de...
# 4            Lycée général et technologique Henri IV
#
#                                            geo_shape date_ouverture  \
# 0  {"coordinates": [[[4.055876699306355, 44.13497...     1965-05-01
# 1  {"coordinates": [[[2.117258236836113, 43.89758...     1965-05-01
# 2  {"coordinates": [[[1.400001302225518, 43.66667...     1965-05-01
# 3  {"coordinates": [[[4.055876699306355, 44.13497...     1965-05-01
# 4  {"coordinates": [[[3.177588429067105, 43.30377...     1965-05-01
#
#   ips_etablissement type_etablissement          numero_voie_et_cote
# 0             101.5              LYCEE  Tous les N°, de  001 à 9999
# 1               125              LYCEE  Tous les N°, de  001 à 9999
# 2             137.2              LYCEE  Tous les N°, de  001 à 9999
# 3             101.5              LYCEE  Tous les N°, de  001 à 9999
# 4              98.3              LYCEE  Tous les N°, de  001 à 9999
#
# [5 rows x 27 columns]

# %% [markdown]
# Statistiques descriptives

# %%
# Dimensions du DataFrame
print(f"Nombre de lignes : {data_carte_scolaire.shape[0]}")
print(f"Nombre de colonnes : {data_carte_scolaire.shape[1]}")

# Statistiques descriptives
data_carte_scolaire.describe(include='all')
# Out:
# Nombre de lignes : 90682
# Nombre de colonnes : 27
#          code_region libelle_region  code_academie libelle_academie  \
# count   90667.000000          90682   90667.000000            90682
# unique           NaN              2            NaN                3
# top              NaN      OCCITANIE            NaN         TOULOUSE
# freq             NaN          90667            NaN            46455
# mean       76.000011            NaN      13.561847              NaN
# std         0.003321            NaN       2.499249              NaN
# min        76.000000            NaN      11.000000              NaN
# 25%        76.000000            NaN      11.000000              NaN
# 50%        76.000000            NaN      16.000000              NaN
# 75%        76.000000            NaN      16.000000              NaN
# max        77.000000            NaN      16.000000              NaN
#
#         code_departement libelle_departement_eleve   code_postal  \
# count       90682.000000                     90682  80606.000000
# unique               NaN                        15           NaN
# top                  NaN                   HERAULT           NaN
# freq                 NaN                     19987           NaN
# mean           37.316469                       NaN  37340.824504
# std            20.539526                       NaN  20219.815801
# min             7.000000                       NaN   9100.000000
# 25%            30.000000                       NaN  30560.000000
# 50%            31.000000                       NaN  31770.000000
# 75%            34.000000                       NaN  34500.000000
# max            82.000000                       NaN  82370.000000
#
#           code_insee com_name_upper                   lieu_dit  ...  code_rne  \
# count   90682.000000          90667                       1453  ...     90682
# unique           NaN           4248                        204  ...       584
# top              NaN       TOULOUSE  STE GENEVIEVE SUR ARGENCE  ...  0120024L
# freq             NaN           8274                        204  ...      1707
# mean    37516.151221            NaN                        NaN  ...       NaN
# std     20504.994869            NaN                        NaN  ...       NaN
# min      7038.000000            NaN                        NaN  ...       NaN
# 25%     30189.000000            NaN                        NaN  ...       NaN
# 50%     31557.000000            NaN                        NaN  ...       NaN
# 75%     34301.000000            NaN                        NaN  ...       NaN
# max     82195.000000            NaN                        NaN  ...       NaN
#
#        libelle_commune                               position adresse_uai  \
# count            90621                                  84807       90682
# unique            1189                                    564         544
# top           Toulouse  43.40141671829832, 3.6919895366938213          NC
# freq              9245                                   1346        6926
# mean               NaN                                    NaN         NaN
# std                NaN                                    NaN         NaN
# min                NaN                                    NaN         NaN
# 25%                NaN                                    NaN         NaN
# 50%                NaN                                    NaN         NaN
# 75%                NaN                                    NaN         NaN
# max                NaN                                    NaN         NaN
#
#        appellation_officielle  \
# count                   84807
# unique                    491
# top       Collège Jean Jaurès
# freq                     1349
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                 geo_shape date_ouverture  \
# count                                               90667          84807
# unique                                               4453            111
# top     {"coordinates": [[[1.400001302225518, 43.66667...     1965-05-01
# freq                                                 8274          39997
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#        ips_etablissement type_etablissement          numero_voie_et_cote
# count              90682              84807                        80526
# unique               335                  2                         2213
# top                   NC              LYCEE  Tous les N°, de  001 à 9999
# freq                6039              43069                        73214
# mean                 NaN                NaN                          NaN
# std                  NaN                NaN                          NaN
# min                  NaN                NaN                          NaN
# 25%                  NaN                NaN                          NaN
# 50%                  NaN                NaN                          NaN
# 75%                  NaN                NaN                          NaN
# max                  NaN                NaN                          NaN
#
# [11 rows x 27 columns]

# %%
# Compter les valeurs manquantes par colonne
missing_values = data_carte_scolaire.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# code_region                      15
# code_academie                    15
# code_postal                   10076
# com_name_upper                   15
# lieu_dit                      89229
# type_et_libelle               10157
# no_de_voie_debut              10156
# no_de_voie_fin                10156
# numero_de_voie                10156
# indice_de_repetition_debut    90481
# indice_de_repetition_fin      90490
# parite                        10156
# libelle_commune                  61
# position                       5875
# appellation_officielle         5875
# geo_shape                        15
# date_ouverture                 5875
# type_etablissement             5875
# numero_voie_et_cote           10156
# dtype: int64

# %%
# Identifier les colonnes catégorielles
categorical_columns = data_carte_scolaire.select_dtypes(include='object').columns

# Afficher les valeurs uniques pour chaque colonne catégorielle
for col in categorical_columns:
    print(f"{col} : {data_carte_scolaire[col].nunique()} valeurs uniques")
    print(data_carte_scolaire[col].value_counts().head())
# Out:
# libelle_region : 2 valeurs uniques
# libelle_region
# OCCITANIE      90667
# HORS REGION       15
# Name: count, dtype: int64
# libelle_academie : 3 valeurs uniques
# libelle_academie
# TOULOUSE       46455
# MONTPELLIER    44212
# HORS REGION       15
# Name: count, dtype: int64
# libelle_departement_eleve : 15 valeurs uniques
# libelle_departement_eleve
# HERAULT          19987
# HAUTE-GARONNE    19233
# GARD             11647
# AUDE              7163
# TARN              7159
# Name: count, dtype: int64
# com_name_upper : 4248 valeurs uniques
# com_name_upper
# TOULOUSE       8274
# MONTPELLIER    6436
# NÎMES          5087
# PERPIGNAN      4092
# BÉZIERS        3664
# Name: count, dtype: int64
# lieu_dit : 204 valeurs uniques
# lieu_dit
# STE GENEVIEVE SUR ARGENCE    204
# DRUELLE                      163
# CARNON PLAGE                  96
# NARBONNE PLAGE                95
# MONTLEGUN                     82
# Name: count, dtype: int64
# type_et_libelle : 27482 valeurs uniques
# type_et_libelle
# RUE DE LA REPUBLIQUE         83
# RUE VICTOR HUGO              57
# CHEMIN DU HAUT BRESIS        57
# RUE VOLTAIRE                 52
# RUE JEAN JACQUES ROUSSEAU    49
# Name: count, dtype: int64
# no_de_voie_debut : 872 valeurs uniques
# no_de_voie_debut
# 001    74812
# 002     1437
# 003      108
# 004       84
# 008       71
# Name: count, dtype: int64
# no_de_voie_fin : 910 valeurs uniques
# no_de_voie_fin
# 9999    74499
# 9998     1264
# 001       119
# 006        89
# 005        79
# Name: count, dtype: int64
# numero_de_voie : 2189 valeurs uniques
# numero_de_voie
# 001 à 9999    73612
# 002 à 9998      388
# 001 à 001       119
# 002 à 002        66
# 002 à 006        60
# Name: count, dtype: int64
# indice_de_repetition_debut : 13 valeurs uniques
# indice_de_repetition_debut
# bis    51
# B      43
# b      43
# a      38
# A       9
# Name: count, dtype: int64
# indice_de_repetition_fin : 16 valeurs uniques
# indice_de_repetition_fin
# a      47
# bis    45
# b      33
# B      31
# A      18
# Name: count, dtype: int64
# parite : 3 valeurs uniques
# parite
# Tous les N°, de    73428
# N° pairs, de        3587
# N° impairs, de      3511
# Name: count, dtype: int64
# code_rne : 584 valeurs uniques
651852], [3.264873106722566, 43.326237120424494], [3.263224408864722, 43.327590530254135], [3.263315194445976, 43.32885153561381], [3.264355128599862, 43.32882740880488], [3.264105737084746, 43.32953149859989], [3.265836444769104, 43.329921280189225], [3.266155120184669, 43.331149339915086], [3.267768388165811, 43.3309159621358], [3.268418069224237, 43.33176266826545], [3.269424835883441, 43.33148668893321], [3.269920997963093, 43.3324390212426], [3.2705915742272, 43.332476028400094], [3.270615319984817, 43.33307150038667], [3.273300829591823, 43.33310792919769], [3.27330770279003, 43.335597092407326], [3.277897775517979, 43.33570504452345], [3.278297689630967, 43.3358308595545], [3.279415976886127, 43.33567414581716], [3.279660243222959, 43.33572479161673], [3.280773998240403, 43.33565083844264], [3.280771468289672, 43.337661445022256], [3.281982204834036, 43.33775365328477], [3.281952194369032, 43.33791745837474], [3.282640109770869, 43.3379570447838], [3.28334263555675, 43.33896275753852], [3.2866200619729, 43.34074072902228], [3.289797864626451, 43.34227597862702], [3.291341724782586, 43.342898854633034], [3.293213917739668, 43.343848275026296], [3.293626238510002, 43.343972201583476], [3.293788844930337, 43.34419486168946], [3.295126045214833, 43.343918642616714], [3.295988606759532, 43.343867707706224], [3.297286756529112, 43.34391002819625], [3.298717802291917, 43.344146280550724], [3.301085519513571, 43.34365033323946], [3.303119408330771, 43.34296635344189], [3.305638163099667, 43.34284411806328], [3.30603428425701, 43.342699061866945], [3.308925652796165, 43.34425975239372], [3.311011844737171, 43.345515020639674], [3.311502571411201, 43.3466803967327], [3.311970147149786, 43.34720891731354], [3.312084720 ...
# Name: count, dtype: int64
# date_ouverture : 111 valeurs uniques
# date_ouverture
# 1965-05-01    39997
# 1969-03-21     2728
# 1973-03-14     2400
# 1972-03-07     2265
# 1970-03-10     2083
# Name: count, dtype: int64
# ips_etablissement : 335 valeurs uniques
# ips_etablissement
# NC       6039
# 109.3    1867
# 111.2    1642
# 115      1586
# 116.4    1458
# Name: count, dtype: int64
# type_etablissement : 2 valeurs uniques
# type_etablissement
# LYCEE      43069
# COLLEGE    41738
# Name: count, dtype: int64
# numero_voie_et_cote : 2213 valeurs uniques
# numero_voie_et_cote
# Tous les N°, de  001 à 9999    73214
# N° impairs, de  001 à 9999       398
# N° pairs, de  002 à 9998         388
# N° impairs, de  001 à 001        119
# N° pairs, de  002 à 002           65
# Name: count, dtype: int64

# %% [markdown]
# Visualisation des points géographiques (= établisements scolaires)

# %%
# Séparer les coordonnées en latitude et longitude
data_carte_scolaire[['latitude', 'longitude']] = data_carte_scolaire['position'].str.split(',', expand=True)

# Convertir les valeurs en type numérique
data_carte_scolaire['latitude'] = pd.to_numeric(data_carte_scolaire['latitude'], errors='coerce')
data_carte_scolaire['longitude'] = pd.to_numeric(data_carte_scolaire['longitude'], errors='coerce')

# Vérifier les premières lignes des colonnes latitude et longitude
print(data_carte_scolaire[['latitude', 'longitude']].head())


plt.figure(figsize=(10, 6))
plt.scatter(data_carte_scolaire['longitude'], data_carte_scolaire['latitude'], alpha=0.5)
plt.title("Répartition géographique des établissements")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
#     latitude  longitude
# 0  44.130077   4.074989
# 1  43.930219   2.147169
# 2  43.603275   1.439895
# 3  44.130077   4.074989
# 4  43.343433   3.210701

# %%
data_carte_scolaire_export = data_carte_scolaire

# Exporter sans numero_de_voie, parite, libelle_commune, position, adresse_uai, appellation_officielle, geo_shape, date_ouverture, ips_etablissement,lieu_dit, latitude,	longitude
data_carte_scolaire_export = data_carte_scolaire_export.drop(columns=['numero_de_voie', 'parite', 'libelle_commune', 'position', 'adresse_uai', 'appellation_officielle', 'geo_shape', 'date_ouverture', 'ips_etablissement','lieu_dit', 'latitude', 'longitude', 'indice_de_repetition_debut',	'indice_de_repetition_fin'])

# Transformer les colonnes no_de_voie_debut et no_de_voie_fin en entiers, enlever la virgule à code_region et code_academie
data_carte_scolaire_export['no_de_voie_debut'] = pd.to_numeric(data_carte_scolaire_export['no_de_voie_debut'], errors='coerce').fillna(0).astype(int)
data_carte_scolaire_export['no_de_voie_fin'] = pd.to_numeric(data_carte_scolaire_export['no_de_voie_fin'], errors='coerce').fillna(0).astype(int)
data_carte_scolaire_export['code_region'] = pd.to_numeric(data_carte_scolaire_export['code_region'], errors='coerce').fillna(0).astype(int)
data_carte_scolaire_export['code_academie'] = pd.to_numeric(data_carte_scolaire_export['code_academie'], errors='coerce').fillna(0).astype(int)


data_carte_scolaire_export.head()
# Out:
#    code_region libelle_region  code_academie libelle_academie  \
# 0           76      OCCITANIE             11      MONTPELLIER
# 1           76      OCCITANIE             16         TOULOUSE
# 2           76      OCCITANIE             16         TOULOUSE
# 3           76      OCCITANIE             11      MONTPELLIER
# 4           76      OCCITANIE             11      MONTPELLIER
#
#    code_departement libelle_departement_eleve  code_postal  code_insee  \
# 0                30                      GARD      30100.0       30007
# 1                81                      TARN      81000.0       81004
# 2                31             HAUTE-GARONNE      31000.0       31555
# 3                30                      GARD      30100.0       30007
# 4                34                   HERAULT      34500.0       34032
#
#   com_name_upper           type_et_libelle  no_de_voie_debut  no_de_voie_fin  \
# 0           ALÈS      IMPASSE ALBERT CAMUS                 1            9999
# 1           ALBI     IMPASSE ALBERT THOMAS                 1            9999
# 2       TOULOUSE  IMPASSE ALEXANDRE YERSIN                 1            9999
# 3           ALÈS      IMPASSE ALFRED CESAR                 1            9999
# 4        BÉZIERS      IMPASSE ALFRED CORNU                 1            9999
#
#    code_rne type_etablissement          numero_voie_et_cote
# 0  0300002P              LYCEE  Tous les N°, de  001 à 9999
# 1  0810006S              LYCEE  Tous les N°, de  001 à 9999
# 2  0310036W              LYCEE  Tous les N°, de  001 à 9999
# 3  0300002P              LYCEE  Tous les N°, de  001 à 9999
# 4  0340009A              LYCEE  Tous les N°, de  001 à 9999

# %%
data_carte_scolaire_export.to_csv('../datasets/data_carte_scolaire_nettoye.csv', index=False)
